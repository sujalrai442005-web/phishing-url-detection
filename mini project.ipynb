# %%
import pandas as pd

# %%
phish = pd.read_csv('phishing_url_dataset.csv')

# %%
phish.head(8)
# Out:
#    url_length  valid_url  at_symbol  sensitive_words_count  path_length  \
# 0          42          0          0                      0           20
# 1          73          0          0                      0           52
# 2          73          0          0                      0           52
# 3          73          0          0                      0           52
# 4          73          0          0                      0           52
# 5          73          0          0                      0           52
# 6          73          0          0                      0           52
# 7          36          0          0                      0            0
#
#    isHttps  nb_dots  nb_hyphens  nb_and  nb_or  nb_www  nb_com  nb_underscore  \
# 0        0        2           0       0      0       1       1              0
# 1        0        5           0       0      0       0       1              0
# 2        0        5           0       0      0       0       1              0
# ...

# %%
phish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2488 entries, 0 to 2487
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   url_length             2488 non-null   int64
#  1   valid_url              2488 non-null   int64
#  2   at_symbol              2488 non-null   int64
#  3   sensitive_words_count  2488 non-null   int64
#  4   path_length            2488 non-null   int64
#  5   isHttps                2488 non-null   int64
#  6   nb_dots                2488 non-null   int64
#  7   nb_hyphens             2488 non-null   int64
#  8   nb_and                 2488 non-null   int64
#  9   nb_or                  2488 non-null   int64
#  10  nb_www                 2488 non-null   int64
#  11  nb_com                 2488 non-null   int64
#  12  nb_underscore          2488 non-null   int64
#  13  target                 2488 non-null   int64
# dtypes: int64(14)
# memory usage: 272.3 KB

# %%
phish.shape
# Out:
# (2488, 14)

# %%
phish.isnull().sum()
# Out:
# url_length               0
# valid_url                0
# at_symbol                0
# sensitive_words_count    0
# path_length              0
# isHttps                  0
# nb_dots                  0
# nb_hyphens               0
# nb_and                   0
# nb_or                    0
# nb_www                   0
# nb_com                   0
# nb_underscore            0
# target                   0
# dtype: int64

# %%
phish.duplicated().sum()
# Out:
# np.int64(1134)

# %%
phish[phish.duplicated()]
# Out:
#       url_length  valid_url  at_symbol  sensitive_words_count  path_length  \
# 2             73          0          0                      0           52
# 4             73          0          0                      0           52
# 5             73          0          0                      0           52
# 6             73          0          0                      0           52
# 8             73          0          0                      0           52
# ...          ...        ...        ...                    ...          ...
# 2481          74          1          0                      0            0
# 2484          74          1          0                      0            0
# 2485          74          1          0                      0            0
# 2486          74          1          0                      0            0
# 2487          74          1          0                      0            0
#
#       isHttps  nb_dots  nb_hyphens  nb_and  nb_or  nb_www  nb_com  \
# ...

# %%
phish.drop_duplicates(inplace=True)

# %%
phish.shape
# Out:
# (1354, 14)

# %%
phish.describe()
# Out:
#         url_length    valid_url    at_symbol  sensitive_words_count  \
# count  1354.000000  1354.000000  1354.000000            1354.000000
# mean     51.794682     0.119645     0.015510               0.150665
# std      20.093369     0.324666     0.331489               0.408035
# min      13.000000     0.000000     0.000000               0.000000
# 25%      31.000000     0.000000     0.000000               0.000000
# 50%      55.000000     0.000000     0.000000               0.000000
# 75%      73.000000     0.000000     0.000000               0.000000
# max      96.000000     1.000000     9.000000               3.000000
#
#        path_length      isHttps      nb_dots   nb_hyphens       nb_and  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000
# mean     15.368538     0.277696     3.953471     0.775480     0.025111
# std      19.320939     0.448028     2.165043     1.402075     0.161172
# ...

# %%
phish.nunique()
# Out:
# url_length               62
# valid_url                 2
# at_symbol                 4
# sensitive_words_count     4
# path_length              59
# isHttps                   2
# nb_dots                  13
# nb_hyphens                9
# nb_and                    3
# nb_or                     4
# nb_www                    3
# nb_com                    4
# nb_underscore             8
# target                    2
# dtype: int64

# %%
phish.to_csv('phish_cleaned.csv',index=False)

# %%
phish.shape
# Out:
# (1354, 14)

# %%
# !pip install ydata-profiling
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Altaf Alam\Desktop\Annacaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Altaf Alam\Desktop\Annacaconda\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\Altaf Alam\Desktop\Annacaconda\Lib\site-packages)

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(phish)
prof. to_file(output_file = 'output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
phish.to_csv('naya_file.csv')
